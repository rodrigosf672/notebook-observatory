# %% [markdown]
# # Title
# Some explanation here.
# More prose.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = np.arange(10)
df = pd.DataFrame({'x': x})
# Out:
# ok

# %%
plt.plot(x)

# %% [markdown]
# ## Conclusion
# That's all.
